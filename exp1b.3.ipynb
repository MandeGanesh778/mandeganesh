# %% [markdown]
# <a href="https://colab.research.google.com/github/MandeGanesh778/mandeganesh/blob/main/exp1b.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Parsing JSON Data from a String

import pandas as pd

from io import StringIO

json_data = """
[
    {
        "Roll_no": 101,
        "Name": "Anusha",
        "Marks":89
    },


    {
            "Roll_no": 102,
            "Name": "Babitha",
            "Marks":92
     },

    {
            "Roll_no": 103,
            "Name": "Charitha",
            "Marks":88
    },

    {
            "Roll_no": 104,
            "Name": "Deepika",
            "Marks":93
    }
]
"""

df = pd.read_json(StringIO(json_data))
print("Parsed JSON Data")
print(df)
# Out:
# Parsed JSON Data
#    Roll_no      Name  Marks
# 0      101    Anusha     89
# 1      102   Babitha     92
# 2      103  Charitha     88
# 3      104   Deepika     93
