# %% [markdown]
# <a href="https://colab.research.google.com/github/MandeGanesh778/mandeganesh/blob/main/exp1b.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_json("students.json")

#Display

print("Students Data..")
print(df)
# Out:
# Students Data..
#    Roll No      Name Department  Marks
# 0      101    Anusha         IT     89
# 1      102   Babitha         IT     92
# 2      103  Charitha        CSE     88
# 3      104   Deepika         DS     85
