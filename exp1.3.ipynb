# %% [markdown]
# <a href="https://colab.research.google.com/github/MandeGanesh778/mandeganesh/blob/main/exp1.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "RollNo": [101, 102, 103],
    "Name": ["Rahul", "Priya", "Akhil"],
    "Marks": [85, 92, 78]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    RollNo   Name  Marks
# 0     101  Rahul     85
# 1     102  Priya     92
# 2     103  Akhil     78
